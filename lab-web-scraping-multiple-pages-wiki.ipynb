# %% [markdown]
# ## WebScraping I: origins

# %%
from bs4 import BeautifulSoup

# %% [markdown]
# ### Now let's try it for real

# %%
import requests

r = requests.get('https://www.billboard.com/charts/hot-100')
r.status_code
# Out:
# 200

# %%
w = requests.get('https://en.wikipedia.org/wiki/List_of_UK_Singles_Chart_number_ones_of_the_2020s#2020')
w.status_code
# Out:
# 200

# %%
html_w = w.content
html_w
# Out:
# b'<!DOCTYPE html>\n<html class="client-nojs" lang="en" dir="ltr">\n<head>\n<meta charset="UTF-8"/>\n<title>List of UK Singles Chart number ones of the 2020s - Wikipedia</title>\n<script>document.documentElement.className="client-js";RLCONF={"wgBreakFrames":!1,"wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","January","February","March","April","May","June","July","August","September","October","November","December"],"wgRequestId":"eb8f263d-be78-4c6c-84af-bda757c80c06","wgCSPNonce":!1,"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":!1,"wgNamespaceNumber":0,"wgPageName":"List_of_UK_Singles_Chart_number_ones_of_the_2020s","wgTitle":"List of UK Singles Chart number ones of the 2020s","wgCurRevisionId":1024412947,"wgRevisionId":1024412947,"wgArticleId":62666386,"wgIsArticle":!0,"wgIsRedirect":!1,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["Articles with short description","Short descripti
# ...

# %%
soup_w = BeautifulSoup(html_w, 'html.parser')
soup_w
# Out:
# <!DOCTYPE html>
#
# <html class="client-nojs" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>List of UK Singles Chart number ones of the 2020s - Wikipedia</title>
# ...

# %%
artist_w = soup_w.find("table", class_="wikitable plainrowheaders sortable").find_all('td')

# %%
artist_w
# Out:
# [<td><a href="/wiki/Ellie_Goulding" title="Ellie Goulding">Ellie Goulding</a>
#  </td>,
#  <td>"<a href="/wiki/River_(Joni_Mitchell_song)#Ellie_Goulding_version" title="River (Joni Mitchell song)">River</a>"
#  </td>,
#  <td><a href="/wiki/Polydor_Records" title="Polydor Records">Polydor</a>
#  </td>,
#  <td><span data-sort-value="000000002020-01-02-0000" style="white-space:nowrap">2 January 2020</span>
#  </td>,
#  <td align="center">1
#  </td>,
#  <td><a href="/wiki/Stormzy" title="Stormzy">Stormzy</a> featuring <a href="/wiki/Ed_Sheeran" title="Ed Sheeran">Ed Sheeran</a> and <a href="/wiki/Burna_Boy" title="Burna Boy">Burna Boy</a>
#  </td>,
#  <td>"<a href="/wiki/Own_It" title="Own It">Own It</a>"
#  </td>,
#  <td><a href="/wiki/Atlantic_Records" title="Atlantic Records">Atlantic</a>/Merky
#  </td>,
#  <td><span data-sort-value="000000002020-01-09-0000" style="white-space:nowrap">9 January 2020</span>
#  </td>,
#  <td align="center">3
#  </td>,
# ...

# %%
rows = []
for i in range(0,len(artist_w),5):
    rows.append(artist_w[i].get_text().strip())

artist_wdf = pd.DataFrame(rows, columns=["artist"])
artist_wdf
# Out:
#                                                artist
# 0                                      Ellie Goulding
# 1          Stormzy featuring Ed Sheeran and Burna Boy
# 2                         Eminem featuring Juice Wrld
# 3                                       Lewis Capaldi
# 4                                          The Weeknd
# 5                                       Billie Eilish
# 6                                          The Weeknd
# 7                                           Saint Jhn
# 8                                          The Weeknd
# 9   Michael Ball, Captain Tom Moore and The NHS Vo...
# 10                               Live Lounge Allstars
# 11                                              Drake
# 12                       DaBaby featuring Roddy Ricch
# 13                        Lady Gaga and Ariana Grande
# 14                       DaBaby featuring Roddy Ricch
# 15                         Jawsh 685 and Jason Derulo
# ...

# %%
song_w = soup_w.find("table", class_="wikitable plainrowheaders sortable").find_all('td')

# %%
song_w
# Out:
# [<td><a href="/wiki/Ellie_Goulding" title="Ellie Goulding">Ellie Goulding</a>
#  </td>,
#  <td>"<a href="/wiki/River_(Joni_Mitchell_song)#Ellie_Goulding_version" title="River (Joni Mitchell song)">River</a>"
#  </td>,
#  <td><a href="/wiki/Polydor_Records" title="Polydor Records">Polydor</a>
#  </td>,
#  <td><span data-sort-value="000000002020-01-02-0000" style="white-space:nowrap">2 January 2020</span>
#  </td>,
#  <td align="center">1
#  </td>,
#  <td><a href="/wiki/Stormzy" title="Stormzy">Stormzy</a> featuring <a href="/wiki/Ed_Sheeran" title="Ed Sheeran">Ed Sheeran</a> and <a href="/wiki/Burna_Boy" title="Burna Boy">Burna Boy</a>
#  </td>,
#  <td>"<a href="/wiki/Own_It" title="Own It">Own It</a>"
#  </td>,
#  <td><a href="/wiki/Atlantic_Records" title="Atlantic Records">Atlantic</a>/Merky
#  </td>,
#  <td><span data-sort-value="000000002020-01-09-0000" style="white-space:nowrap">9 January 2020</span>
#  </td>,
#  <td align="center">3
#  </td>,
# ...

# %%
rows = []
for i in range(1,len(artist_w),5):
    rows.append(artist_w[i].find('a').get_text())

song_wdf = pd.DataFrame(rows, columns=["song"])
song_wdf
# Out:
#                                 song
# 0                              River
# 1                             Own It
# 2                           Godzilla
# 3                      Before You Go
# 4                    Blinding Lights
# 5                     No Time to Die
# 6                    Blinding Lights
# 7                              Roses
# 8                    Blinding Lights
# 9            You'll Never Walk Alone
# 10                  Times Like These
# 11                      Toosie Slide
# 12                          Rockstar
# 13                        Rain on Me
# 14                          Rockstar
# 15  Savage Love (Laxed – Siren Beat)
# 16                      Head & Heart
# 17                               WAP
# 18                              Mood
# 19                          Lemonade
# 20                         Positions
# 21   All I Want for Christmas Is You
# 22              Don't Stop Me Eatin'
# 23                    Last Christmas
# ...

# %%
chart_w = pd.concat([artist_wdf, song_wdf], axis=1)
chart_w
# Out:
#                                                artist  \
# 0                                      Ellie Goulding
# 1          Stormzy featuring Ed Sheeran and Burna Boy
# 2                         Eminem featuring Juice Wrld
# 3                                       Lewis Capaldi
# 4                                          The Weeknd
# 5                                       Billie Eilish
# 6                                          The Weeknd
# 7                                           Saint Jhn
# 8                                          The Weeknd
# 9   Michael Ball, Captain Tom Moore and The NHS Vo...
# 10                               Live Lounge Allstars
# 11                                              Drake
# 12                       DaBaby featuring Roddy Ricch
# 13                        Lady Gaga and Ariana Grande
# 14                       DaBaby featuring Roddy Ricch
# 15                         Jawsh 685 and Jason Derulo
# ...
